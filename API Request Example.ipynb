# %%
import requests
import yaml
import pandas as pd

# %%
credentials = yaml.load(open('github.yaml'))
api_key = credentials['GITHUB_KEY']

# %%
response = requests.get(
    'https://api.github.com/users/dlwong/repos',
    headers={'Authorization': 'token '+api_key}
)

# %%
df = pd.DataFrame(response.json())

# %%
df.head()
# Out:
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/dlwong/6ees6ees6e...     False
# 1  https://api.github.com/repos/dlwong/a-synchron...     False
# 2  https://api.github.com/repos/dlwong/beesbeesbe...     False
# 3  https://api.github.com/repos/dlwong/bookbeats/...     False
# 4  https://api.github.com/repos/dlwong/chatterbox...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/dlwong/6ees6ees6e...
# 1  https://api.github.com/repos/dlwong/a-synchron...
# 2  https://api.github.com/repos/dlwong/beesbeesbe...
# 3  https://api.github.com/repos/dlwong/bookbeats/...
# 4  https://api.github.com/repos/dlwong/chatterbox...
#
#                                            blobs_url  \
# 0  https://api.github.com/repos/dlwong/6ees6ees6e...
# 1  https://api.github.com/repos/dlwong/a-synchron...
# 2  https://api.github.com/repos/dlwong/beesbeesbe...
# ...
